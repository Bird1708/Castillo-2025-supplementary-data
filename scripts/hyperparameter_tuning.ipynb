# %%
import numpy as np
from numpy.random import default_rng
import pandas as pd
from hyperopt import hp, fmin, tpe, space_eval, STATUS_OK, Trials
from xgboost import XGBClassifier
from imblearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
import warnings
import json

method = 'TCP_LT_AOF'
data = pd.read_csv(f'../input_data/{method}/data.csv')

parameters = ['normal_convergence_rate', 
              'subducting_ocean_floor_age',
              'obliquity_of_subduction',
              'migration_rate_x_distance']

X = data[parameters]
y = data['cu_mt']
y_cat = np.where(y > 2, 1, 0)

# Define a hyperparameter search space 
# Bounds below are indicative only.
# Users may adjust ranges, distributions, or include/exclude parameters.
# Different choices (broad vs constrained) lead to comparable global conclusions.

space = hp.choice('classifiers', [
    {
        'model': XGBClassifier(seed=42),
        'params': {
            'model__max_depth': hp.choice('xgb.max_depth', range(DEPTH_MIN, DEPTH_MAX)),
            'model__learning_rate': hp.uniform('xgb.learning_rate', LR_MIN, LR_MAX),
            'model__n_estimators': hp.choice('xgb.n_estimators', range(N_EST_MIN, N_EST_MAX)),
            'model__reg_lambda': hp.uniform('xgb.reg_lambda', LAMBDA_MIN, LAMBDA_MAX),
            'model__reg_alpha': hp.uniform('xgb.reg_alpha', ALPHA_MIN, ALPHA_MAX),
            'model__gamma': hp.uniform('xgb.gamma', GAMMA_MIN, GAMMA_MAX),
            'model__min_child_weight': hp.quniform('xgb.min_child_weight', MCW_MIN, MCW_MAX, 1),
            'model__subsample': hp.uniform('xgb.subsample', SUBSAMPLE_MIN, 1.0),
            'model__colsample_bytree': hp.uniform('xgb.colsample_bytree', COLSAMPLE_MIN, 1.0),
            'model__scale_pos_weight': hp.quniform('xgb.scale_pos_weight', SPW_MIN, SPW_MAX, 1)
        }
    }
])

# Define the objective function to optimize
def objective(args):
    pipeline = Pipeline(steps=[
        ('model', args['model'])
    ])

    pipeline.set_params(**args['params'])
    rskf = RepeatedStratifiedKFold(n_splits=5, n_repeats=10, random_state=42) 
    score = cross_val_score(pipeline, X, y_cat, cv=rskf, scoring='f1', n_jobs=-1) # Cross-validations with F1 score as evaluation metric (can use other built-in metrics or a custom loss function)
    
    return {'loss': -np.mean(score), 'status': STATUS_OK} 

trials = Trials()
rng = default_rng(42) 
best_classifier = fmin(objective, space, algo=tpe.suggest, max_evals=1000, trials=trials, rstate=rng)

best_params = space_eval(space, best_classifier) 
print(best_params['params']) # Retrieve the best hyperparameters

with open('final_hyperparameters.json', 'w') as f:
    json.dump(best_params['params'], f, indent=4)
